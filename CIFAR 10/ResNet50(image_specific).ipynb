# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanJadhao/CIFAR-10/blob/main/ResNet50(image_specific).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
model = ResNet50(weights='imagenet')

# %%
img1_path = "/content/airplane.jpeg"
img = image.load_img(img1_path, target_size=(224,224,3))
X = image.img_to_array(img)
X = np.expand_dims(X, axis=0)
X = preprocess_input(X)

# %%
pred = model.predict(X)
print("Predictions : ", decode_predictions(pred, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predictions :  [('n02690373', 'airliner', np.float32(0.99352336)), ('n04552348', 'warplane', np.float32(0.005314606)), ('n04592741', 'wing', np.float32(0.00092345726))]

# %%
img2_path = "/content/monkey img.jpeg"
img = image.load_img(img2_path, target_size=(224,224,3))
X = image.img_to_array(img)
X = np.expand_dims(X, axis=0)
X = preprocess_input(X)

# %%
pred = model.predict(X)
print("Predictions : ", decode_predictions(pred, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predictions :  [('n02493509', 'titi', np.float32(0.41249937)), ('n02487347', 'macaque', np.float32(0.24168041)), ('n02492035', 'capuchin', np.float32(0.117837764))]
